# %%
import pandas as pd
import re

# %%
original = pd.read_excel("SEIA2/seia_3_5_2019.xls")

# %%
original.head()
# Out:
#                                               Nombre Tipo    Región  \
# 0            Continuidad Operacional Mina Dos Amigos  DIA   Tercera
# 1         Construcción Hospital Provincia Cordillera  DIA        RM
# 2  Modificación de Proyecto Técnico. Centro de En...  DIA  Undécima
# 3  CULTIVO COMERCIAL DE DORADO (Seriola lalandi),...  DIA   Tercera
# 4  CULTIVO COMERCIAL DE DORADO (Seriola lalandi),...  DIA   Tercera
#
#        Comunas                                         Provincias Tipología  \
# 0     Vallenar                            Chaqaral-Copiapó-Huasco        i1
# 1  Puente Alto  Chacabuco-Santiago-Talagante-Melipilla-Maipo-C...        h1
# 2        Aysén       Aysen-Coyhaique-General Carrera-Capitan Prat        n3
# 3       Huasco                            Chaqaral-Copiapó-Huasco        n3
# 4       Huasco                            Chaqaral-Copiapó-Huasco        n3
#
#                              Titular  Inversión (MMU$)  Fecha presentación  \
# 0  Compañia Explotadora de Minas SpA              10.0 2019-05-03 21:10:00
# 1                  SACYR CHILE S.A..             152.0 2019-05-03 20:48:48
# 2             Salmones ICE VAL Ltda.               2.0 2019-05-03 16:37:22
# 3      Luis Alejandro Salgado Ibáñez               7.0 2019-05-03 15:59:59
# 4      Luis Alejandro Salgado Ibáñez               7.0 2019-05-03 15:59:59
#
#                       Estado  Fecha calificación    Sector productivo  \
# 0                En Admisión                 NaT              Minería
# 1            En Calificación                 NaT        Inmobiliarios
# 2                En Admisión                 NaT  Pesca y Acuicultura
# 3  No Admitido a Tramitación 2019-05-02 15:59:59  Pesca y Acuicultura
# 4  No Admitido a Tramitación 2019-05-02 15:59:59  Pesca y Acuicultura
#
#    Latitud punto representativo  Longitud punto representativo
# 0                    -29.000000                     -71.000000
# 1                    -33.613423                     -70.600776
# 2                    -45.000000                     -73.000000
# 3                    -28.325610                     -71.199366
# 4                    -28.153737                     -71.179471

# %%
original = original.drop(['Región','Provincias'], axis=1)
original.head()
# Out:
#                                               Nombre Tipo      Comunas  \
# 0            Continuidad Operacional Mina Dos Amigos  DIA     Vallenar
# 1         Construcción Hospital Provincia Cordillera  DIA  Puente Alto
# 2  Modificación de Proyecto Técnico. Centro de En...  DIA        Aysén
# 3  CULTIVO COMERCIAL DE DORADO (Seriola lalandi),...  DIA       Huasco
# 4  CULTIVO COMERCIAL DE DORADO (Seriola lalandi),...  DIA       Huasco
#
#   Tipología                            Titular  Inversión (MMU$)  \
# 0        i1  Compañia Explotadora de Minas SpA              10.0
# 1        h1                  SACYR CHILE S.A..             152.0
# 2        n3             Salmones ICE VAL Ltda.               2.0
# 3        n3      Luis Alejandro Salgado Ibáñez               7.0
# 4        n3      Luis Alejandro Salgado Ibáñez               7.0
#
#    Fecha presentación                     Estado  Fecha calificación  \
# 0 2019-05-03 21:10:00                En Admisión                 NaT
# 1 2019-05-03 20:48:48            En Calificación                 NaT
# 2 2019-05-03 16:37:22                En Admisión                 NaT
# 3 2019-05-03 15:59:59  No Admitido a Tramitación 2019-05-02 15:59:59
# 4 2019-05-03 15:59:59  No Admitido a Tramitación 2019-05-02 15:59:59
#
#      Sector productivo  Latitud punto representativo  \
# 0              Minería                    -29.000000
# 1        Inmobiliarios                    -33.613423
# 2  Pesca y Acuicultura                    -45.000000
# 3  Pesca y Acuicultura                    -28.325610
# 4  Pesca y Acuicultura                    -28.153737
#
#    Longitud punto representativo
# 0                     -71.000000
# 1                     -70.600776
# 2                     -73.000000
# 3                     -71.199366
# 4                     -71.179471

# %%
original = original.drop(original[original.Estado=='En Admisión'].index)
original.head()
# Out:
#                                               Nombre Tipo      Comunas  \
# 1         Construcción Hospital Provincia Cordillera  DIA  Puente Alto
# 3  CULTIVO COMERCIAL DE DORADO (Seriola lalandi),...  DIA       Huasco
# 4  CULTIVO COMERCIAL DE DORADO (Seriola lalandi),...  DIA       Huasco
# 5                        Edificio Irarrazaval N°1171  DIA        Ñuñoa
# 6  CULTIVO COMERCIAL DE DORADO (Seriola lalandi),...  DIA      Caldera
#
#   Tipología                              Titular  Inversión (MMU$)  \
# 1        h1                    SACYR CHILE S.A..             152.0
# 3        n3        Luis Alejandro Salgado Ibáñez               7.0
# 4        n3        Luis Alejandro Salgado Ibáñez               7.0
# 5        h1  ARRENDAMIENTOS IRARRAZABAL 1171 SPA              30.0
# 6        n3        Luis Alejandro Salgado Ibáñez               7.0
#
#    Fecha presentación                     Estado  Fecha calificación  \
# 1 2019-05-03 20:48:48            En Calificación                 NaT
# 3 2019-05-03 15:59:59  No Admitido a Tramitación 2019-05-02 15:59:59
# 4 2019-05-03 15:59:59  No Admitido a Tramitación 2019-05-02 15:59:59
# 5 2019-05-02 17:49:44            En Calificación                 NaT
# 6 2019-05-02 15:59:59  No Admitido a Tramitación 2019-05-02 15:59:59
#
#      Sector productivo  Latitud punto representativo  \
# 1        Inmobiliarios                    -33.613423
# 3  Pesca y Acuicultura                    -28.325610
# 4  Pesca y Acuicultura                    -28.153737
# 5        Inmobiliarios                    -33.453632
# 6  Pesca y Acuicultura                    -27.214968
#
#    Longitud punto representativo
# 1                     -70.600776
# 3                     -71.199366
# 4                     -71.179471
# 5                     -70.618586
# 6                     -70.969612

# %%
original = original.sort_values(by='Fecha presentación')

# %%
original.reset_index(drop=True,inplace=True)
original.head()
#original.iloc[100:110]
# Out:
#                                           Nombre Tipo      Comunas Tipología  \
# 0                  Fundición REFIMET Antofagasta  EIA  Antofagasta         t
# 1  Cobre en Cátodos en Planta Coloso-Antofagasta  EIA  Antofagasta        i4
# 2              Planta Integrada Productos Tissue  EIA    Talagante        m4
# 3                                       Zaldivar  EIA  Antofagasta        i4
# 4                                      Las Luces  DIA       Taltal        i4
#
#                         Titular  Inversión (MMU$)  Fecha presentación  \
# 0        FUNDICION REFIMET S.A.              60.0 1992-06-13 15:59:59
# 1     MINERA ESCONDIDA LIMITADA             250.0 1992-07-29 15:59:59
# 2              CMPC Tissue S.A.              60.0 1993-04-02 15:59:59
# 3  Compañía Minera Zaldívar SpA             600.0 1993-05-01 15:59:59
# 4       Minera Las Cenizas S.A.              15.0 1993-06-15 15:59:59
#
#      Estado  Fecha calificación Sector productivo  \
# 0  Aprobado 1993-09-13 15:59:59             Otros
# 1  Aprobado 1993-01-04 14:59:59           Minería
# 2  Aprobado 1993-09-16 15:59:59          Forestal
# 3  Aprobado 1993-10-08 15:59:59           Minería
# 4  Aprobado 1993-11-29 14:59:59           Minería
#
#    Latitud punto representativo  Longitud punto representativo
# 0                    -23.820454                     -70.315629
# 1                    -23.762165                     -70.469255
# 2                    -33.706950                     -70.935728
# 3                    -24.212938                     -69.051889
# 4                    -25.699649                     -70.499074

# %%
#comc = original[original['Comunas'].str.match(r'^[a-z A-Z]+-([a-z A-Z]+)?$',na=False)]
#comc = comc[~comc['Comunas'].str.contains('Til')]
#comc[['Comunas']].head(1000)
# Out:
#                                                 Nombre Tipo  \
# 100   Sistema de Transmisión Colbun-Alto Jahuel 220 KV  EIA
# 101       Relleno Sanitario Sector Colihues - La Yesca  EIA
# 102                  Centro Invernal Valle Nevado 3000  EIA
# 103               Proyecto Lagunas Soquimich-Lodo S.A.  EIA
# 104               Ampliación Planta de Cemento INACESA  EIA
# 105                    Ampliación Astillero de Caldera  EIA
# 106        Planta de Remanufacturera Innocenti Gajardo  EIA
# 107    Estudio Integral Tranques Relaves Pastos Largos  EIA
# 108  Central Termoeléctrica de Ciclo Combinado Cent...  EIA
# 109  Central Termoeléctrica de Ciclo Combinado Nehu...  EIA
#
#                                            Comunas Tipología  \
# 100  Machalí-Buin-Codegua-Rengo-Chimbarongo-Colbún        b1
# 101                                       Requinoa        o5
# 102                                   Lo Barnechea        g4
# 103                                   Pozo Almonte        i4
# 104                                    Antofagasta        k1
# 105                                        Caldera        f3
# 106                                    Los Angeles        m3
# 107                                         Vicuña        i4
# 108                                       Quillota         c
# 109                                       Quillota         c
#
#                                        Titular  Inversión (MMU$)  \
# 100                      Colbún Transmisión SA             72.00
# 101          Ilustre Municipalidad de Rancagua              0.17
# 102                   Empresa Spie Batignolles            150.00
# 103                              SQM IODO S.A.             16.89
# 104                    Bio Bio Cementos   S.A.             46.00
# 105  Astilleros Maestranzas Navales de Caldera              0.20
# 106                  Innocenti y Gajardo Ltda.              2.60
# 107            CIA. MINERA BARRICK CHILE LTDA.              2.81
# 108           Compañía Eléctrica Tarapacá S.A.            200.00
# 109                                Colbún S.A.            220.00
#
#      Fecha presentación    Estado  Fecha calificación  \
# 100 1996-04-30 15:59:59  Aprobado 1997-01-17 14:59:59
# 101 1996-05-07 15:59:59  Aprobado 1996-11-15 14:59:59
# 102 1996-06-10 15:59:59  Aprobado 1997-08-11 15:59:59
# 103 1996-06-17 15:59:59  Aprobado 1997-01-31 14:59:59
# 104 1996-07-08 15:59:59  Aprobado 1998-01-23 14:59:59
# 105 1996-07-08 15:59:59  Aprobado 1997-04-04 15:59:59
# 106 1996-07-22 15:59:59  Aprobado 1997-04-07 15:59:59
# 107 1996-08-14 15:59:59  Aprobado 1997-01-16 14:59:59
# 108 1996-08-14 15:59:59  Aprobado 1997-05-05 15:59:59
# 109 1996-08-16 15:59:59  Aprobado 1997-05-05 15:59:59
#
#                  Sector productivo  Latitud punto representativo  \
# 100                        Energía                    -35.685375
# 101          Saneamiento Ambiental                    -34.231782
# 102                  Inmobiliarios                    -33.353552
# 103                        Minería                    -20.951725
# 104  Instalaciones fabriles varias                    -23.781178
# 105      Infraestructura Portuaria                    -27.063102
# 106                       Forestal                    -37.550697
# 107                        Minería                    -29.792534
# 108                        Energía                    -32.937031
# 109                        Energía                    -32.936992
#
#      Longitud punto representativo
# 100                     -71.381807
# 101                     -70.704146
# 102                     -70.248715
# 103                     -69.671107
# 104                     -70.318845
# 105                     -70.831287
# 106                     -72.556500
# 107                     -69.998943
# 108                     -71.316290
# 109                     -71.321785

# %%
comunas = []

for i in range(len(original)):
    try:
        split = original.iloc[i]['Comunas'].split('-')
    except:
        print(i,'NaN?')
    tilted = False
    for s in split:
        if (s=='Til'):
            if(not tilted):
                comunas.append([i,'TILTIL'])
                tilted=True
        else:
            comunas.append([i,s.upper()])

comunas_nuevas = pd.DataFrame(comunas, columns = ['id_proyecto', 'comuna'])
# Out:
# 1307 NaN?
# 2977 NaN?

# %%
comunas_nuevas.head()
# Out:
#    id_proyecto       comuna
# 0            0  ANTOFAGASTA
# 1            1  ANTOFAGASTA
# 2            2    TALAGANTE
# 3            3  ANTOFAGASTA
# 4            4       TALTAL

# %%
codigos_comuna = pd.read_csv("Localidades/comunas.csv")
codigos_comuna['Nombre Comuna'] = codigos_comuna['Nombre Comuna'].str.upper()
codigos_comuna.head()
# Out:
#    Código Comuna 2017  Nombre Comuna  Código Provincia
# 0                1101        IQUIQUE                11
# 1                1107  ALTO HOSPICIO                11
# 2                1401   POZO ALMONTE                14
# 3                1402         CAMIÑA                14
# 4                1403       COLCHANE                14

# %%
codigos_comuna = codigos_comuna.drop(['Código Provincia'], axis=1)

# %%
final = comunas_nuevas.join(codigos_comuna.set_index('Nombre Comuna'),on='comuna')
final = final.rename(columns = {'comuna':'nombre_comuna','Código Comuna 2017':'comuna'})
#final['comuna'] = final['comuna'].astype(int) 
#final.loc[final.comuna.isnull()].drop_duplicates(subset='nombre_comuna')
final.head()
# Out:
#    id_proyecto nombre_comuna   comuna
# 0            0   ANTOFAGASTA   2101.0
# 1            1   ANTOFAGASTA   2101.0
# 2            2     TALAGANTE  13601.0
# 3            3   ANTOFAGASTA   2101.0
# 4            4        TALTAL   2104.0

# %%
#Reemplazar valores de comunas_nuevas por valores correspondientes a los codigos
comunas_fixed = comunas_nuevas.replace({'SAN JOSÉ DE LA MARIQUINA':'MARIQUINA',
                                        'SAN JOSÉ DE LA MARIQU':'MARIQUINA',
                                        'REQUINOA':'REQUÍNOA',
                                        'REQUI':'REQUÍNOA',
                                        'LA CALERA':'CALERA',
                                        'AYSÉN':'AISÉN',
                                        'COYHAIQUE':'COIHAIQUE',
                                        'COYHAI':'COIHAIQUE',
                                        'LLAY LLAY':'LLAILLAY',
                                        'PUERTO SAAVEDRA':'SAAVEDRA',
                                        'LAS GUAITECAS':'GUAITECAS',
                                        'TREHUACO':'TREGUACO',
                                        'VILLA OHIGGINS':'O\'HIGGINS'})
#Completar valores incompletos de ser posible
fix = final.loc[final.comuna.isnull()].drop_duplicates(subset='nombre_comuna')['nombre_comuna'].tolist()
rep = {}
for n in fix:
    lu =codigos_comuna.loc[codigos_comuna['Nombre Comuna'].str.match(re.escape(n)+'.*')]
    if len(lu)==1:
        rep[n]=lu.iloc[0]['Nombre Comuna']
comunas_fixed = comunas_fixed.replace(rep)
comunas_fixed.head()
# Out:
#    id_proyecto       comuna
# 0            0  ANTOFAGASTA
# 1            1  ANTOFAGASTA
# 2            2    TALAGANTE
# 3            3  ANTOFAGASTA
# 4            4       TALTAL

# %%
codigos_comuna.loc[codigos_comuna['Nombre Comuna'].str.contains('PICHI')]
# Out:
#     Código Comuna 2017 Nombre Comuna
# 90                6113    PICHIDEGUA
# 95                6201     PICHILEMU

# %%
intermedio = comunas_fixed.join(codigos_comuna.set_index('Nombre Comuna'),on='comuna')
intermedio = intermedio.rename(columns = {'comuna':'nombre_comuna','Código Comuna 2017':'comuna'})
#nombres de comunas incompletables
incomp = intermedio.loc[intermedio.comuna.isnull()].drop_duplicates(subset='nombre_comuna')
incomp.head()
#print(len(incomp))
# Out:
#       id_proyecto nombre_comuna  comuna
# 3416         2857                   NaN
# 3742         3117            PI     NaN
# 3815         3162          PEÑA     NaN
# 4079         3369            TI     NaN
# 5143         4267           LO      NaN

# %%
estesi = intermedio.drop(intermedio.loc[intermedio.comuna.isnull()].index)

# %%
estesi.head()
# Out:
#    id_proyecto nombre_comuna   comuna
# 0            0   ANTOFAGASTA   2101.0
# 1            1   ANTOFAGASTA   2101.0
# 2            2     TALAGANTE  13601.0
# 3            3   ANTOFAGASTA   2101.0
# 4            4        TALTAL   2104.0

# %%
comunasEnProyectos = estesi.drop(['nombre_comuna'],axis=1)
comunasEnProyectos['comuna'] = comunasEnProyectos['comuna'].astype(int)
comunasEnProyectos.set_index('id_proyecto',drop=True, inplace=True)
comunasEnProyectos.head()
# Out:
#              comuna
# id_proyecto
# 0              2101
# 1              2101
# 2             13601
# 3              2101
# 4              2104

# %%
proyectos = original.drop(['Comunas'],axis=1)[['Nombre','Tipo','Tipología','Titular','Inversión (MMU$)','Estado','Fecha presentación','Fecha calificación','Sector productivo','Latitud punto representativo','Longitud punto representativo']]

# %%
proyectos.head()
# Out:
#                                           Nombre Tipo Tipología  \
# 0                  Fundición REFIMET Antofagasta  EIA         t
# 1  Cobre en Cátodos en Planta Coloso-Antofagasta  EIA        i4
# 2              Planta Integrada Productos Tissue  EIA        m4
# 3                                       Zaldivar  EIA        i4
# 4                                      Las Luces  DIA        i4
#
#                         Titular  Inversión (MMU$)    Estado  \
# 0        FUNDICION REFIMET S.A.              60.0  Aprobado
# 1     MINERA ESCONDIDA LIMITADA             250.0  Aprobado
# 2              CMPC Tissue S.A.              60.0  Aprobado
# 3  Compañía Minera Zaldívar SpA             600.0  Aprobado
# 4       Minera Las Cenizas S.A.              15.0  Aprobado
#
#    Fecha presentación  Fecha calificación Sector productivo  \
# 0 1992-06-13 15:59:59 1993-09-13 15:59:59             Otros
# 1 1992-07-29 15:59:59 1993-01-04 14:59:59           Minería
# 2 1993-04-02 15:59:59 1993-09-16 15:59:59          Forestal
# 3 1993-05-01 15:59:59 1993-10-08 15:59:59           Minería
# 4 1993-06-15 15:59:59 1993-11-29 14:59:59           Minería
#
#    Latitud punto representativo  Longitud punto representativo
# 0                    -23.820454                     -70.315629
# 1                    -23.762165                     -70.469255
# 2                    -33.706950                     -70.935728
# 3                    -24.212938                     -69.051889
# 4                    -25.699649                     -70.499074

# %%
comunasEnProyectos.to_csv("SEIA2/ForDB/comunas_de_proyectos.csv")
proyectos.to_csv("SEIA2/ForDB/proyectos.csv")
